# %% [markdown]
# # Hierarchical cluster analysis
#
# Hierarchical clustering, also known as hierarchical cluster analysis, is an algorithm that groups similar objects into groups called clusters. The endpoint is a set of clusters, where each cluster is distinct from each other cluster, and the objects within each cluster are broadly similar to each other.
#
#
# - The first step in the hierarchical clustering process is to look for the pair of samples that are so similar
# - the only problem is how to calculated the dissimilarity between the merged pair
# - We use maximum or complete Linkage

# %% [markdown]
# ## Complete Linkage
#
# - method: the dissimilarity between the merged pair and the others will be the maximum of the pair of dissimilarities in each case.
#
# - For example, the dissimilarity between B and A is 0.5000, while the dissimilarity between F and A is 0.6250.
# - hence we choose the maximum of the two, 0.6250, to quantify the dissimilarity between ( B , F ) and A.

# %% [markdown]
# ## Dendogram
#
# ![image.png](attachment:image.png)

# %% [markdown]
# ![image.png](attachment:image.png)

# %% [markdown]
# ## Cutting of tree
#
# ![image.png](attachment:image.png)
#
# - We cut from Y-axis to the dendogram which include all member
# - how many time the line cutting to graph is the value of cluter

# %% [markdown]
# ![image.png](attachment:image.png)
