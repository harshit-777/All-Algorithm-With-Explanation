# %% [markdown]
# # K-Means
#
#
# - The k-means algorithm attempts to find discrete groupings within data, where members of a group are as similar as possible to one another and as different as possible from members of other groups (see the following figure). You define the attributes that you want the algorithm to use to determine similarity.
#
#
# ## Where TO Use K-means?
#
# - The k-means algorithm can be a good fit for finding patterns or groups in large datasets that have not been explicitly labeled. Here are some example use cases in different domains:
#
# - E-commerce
# Classifying customers by purchase history or clickstream activity.
# Healthcare
# - Detecting patterns for diseases or success treatment scenarios.
# Grouping similar images for image detection.
# - Finance
# Detecting fraud by detecting anomalies in the dataset. For example, detecting credit card frauds by abnormal purchase patterns.
# - Technology
# Building a network intrusion detection system that aims to identify attacks or malicious activity.
# - Meteorology
# Detecting anomalies in sensor data collection such as storm forecasting.
#
#
# ## Alogrithm
# - Unsupervised Learning
# - Groups in cluster
# - we intialize the centriod randomly
# - from two centroid of cluster we calculate the distance
# - Distance is calculated on the basic of Eucledian Distance
# - The Line perpendicular to eucledian line drawn
# - THe points above are converted into same color
# - Below in same color
# - Again randomly Centroid is choosen again same steps are followed
# - We do until we dont see any movment of data points
#
#
# ![image.png](attachment:image.png)

# %% [markdown]
# ![image.png](attachment:image.png)

# %% [markdown]
# ## Step1 - Initialize the centroid
#
# The second step is to allocate K random points as centroids. These K points could be points from the dataset or outside.
#
# ![image.png](attachment:image.png)

# %% [markdown]
# ## Step2 - Eucledian Distance
# ![image.png](attachment:image.png)

# %% [markdown]
# ## Step3 - Update Means
#
# - m = (m*(n-1)+x)/n
#
#
#
# where m is the mean value for a feature, n is the number of items in the cluster and x is the feature value for the added item. We do the above for each feature to get the new mean.

# %% [markdown]
# ## Step3 - Draw parpendicular
#
# - Dwaring Perpndi to distance of centroid the above points will assign in one cluster and below will be in one cluster
# ![image.png](attachment:image.png)

# %% [markdown]
# ## Step4 - Compute New Centroid
#
# ![image.png](attachment:image.png)

# %% [markdown]
# ![image.png](attachment:image.png)

# %% [markdown]
# ## Summary
#
# ![image.png](attachment:image.png)

# %% [markdown]
# ## Elbow Method - K value

# %% [markdown]
# The way to evaluate the choice of K is made using a parameter known as WCSS. WCSS stands for Within Cluster Sum of Squares. It should be low. Here's the formula representation for example when K = 3
#
# Summation Distance(p,c) is the sum of distance of points in a cluster from the centroid.
#
#
# ![image.png](attachment:image.png)
#
#
#
# The Elbow Method is then used to choose the best K value. In the depiction below we can see that after 4 there's no significant decrease in WCSS so 4 is the best here. Therefore there's an elbow shape that forms and it is usually a good idea to pick the number where this elbow is formed.

# %% [markdown]
# ![image.png](attachment:image.png)

# %% [markdown]
# ## K-means Problem
#
# ![image.png](attachment:image.png)

# %% [markdown]
# # Loyad Algorithm
#
#
# - Choose K with arbitary centres
# - Perform Local Search till convergence
# - Simple and sclable
#
# Disad-
#
# - Long time,to may iteration
# - Random inti 2 cluster in same cluster
# - Stuck in local optimum
# - K-means will always converge,
#
# TO SOLVE PROBLEM K-MEANS++ USED

# %% [markdown]
# ## K-mens++  --- init='kmeans++'
#
# - Speards out centre
# - Choose First Centre at random of data
# - Select the next centroid from the data points such that the probability of choosing a point as centroid is directly proportional to its distance from the nearest, previously chosen centroid.
#
# ![image.png](attachment:image.png)
#
#
#
# O(logK) = optimum
#
#
# ADV-
# - in each step the probability of choosing outlier will be grater
# - coz here we take propotional of probality of distance
# - If K will be more theb more data points will cover
# - It Scale cost down
# - K means reduces Loyal iteration
#
#
# DIAD-
# - LArge dataset need K also large
# - Do not Sclae
#
# TO SOLVE THE PROBLEM-
#
# - Sample at one point update its distortion
# - Oversmple - Update much more Frequently
# - Coarsar Sampling
# - If K=1 then ovrsampling will choose each point independently
# - we increase

# %% [markdown]
# ## Random Intialization Trap in K-Means
#
# Random initialization trap is a problem that occurs in the K-means algorithm. In random initialization trap when the centroids of the clusters to be generated are explicitly defined by the User then inconsistency may be created and this may sometimes lead to generating wrong clusters in the dataset. So random initialization trap may sometimes prevent us from developing the correct clusters.
#
# ![image.png](attachment:image.png)

# %% [markdown]
# ### First Trial
# ![image.png](attachment:image.png)

# %% [markdown]
# ### First Final Model
# ![image.png](attachment:image.png)

# %% [markdown]
# ### Second Trial
# Consider another case in which we choose another set of centroids for the dataset as shown. Now the set of clusters generated will be different from the clusters generated in the previous practice.
#
# ![image.png](attachment:image.png)

# %% [markdown]
# ### Second Final Model
#
# ![image.png](attachment:image.png)

# %%
init = 'kmeans++'
n_jobs = K-means to run parallel #increase computation cost of memory
