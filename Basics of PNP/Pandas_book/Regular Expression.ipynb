# %% [markdown]
# # Regular-
#
# - Regular expressions provide a flexible way to search or match (often more complex) string patterns in text. A single expression, commonly called a regex,

# %%
import re

# %% [markdown]
# ## +s

# %%
text = "aa     bbb \t bbb  \t cc"

# %%
regx = re.compile('/s+')

# %%
regx.split(text)
# Out:
# ['aa     bbb \t bbb  \t cc']

# %%
re.split('\+s',text)
# Out:
# ['aa     bbb \t bbb  \t cc']
