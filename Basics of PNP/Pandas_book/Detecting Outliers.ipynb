# %%
data = pd.DataFrame(np.random.randn(1000,4))

# %%
data
# Out:
#             0         1         2         3
# 0    0.910772  0.219593  0.124492  0.250015
# 1   -0.457655  0.588858  0.827315 -1.613518
# 2   -0.111487  2.573879 -0.754297 -0.959140
# 3    0.358919  1.081845 -0.089747  0.002477
# 4   -2.161612  1.994437 -0.620995  0.083107
# 5   -0.236611 -1.218105 -0.047355 -0.033110
# 6    1.502327 -1.456690 -1.122369 -1.276462
# 7   -0.592183 -0.116131  0.513902 -1.486584
# 8   -1.695852 -0.335408  2.158982 -0.281345
# 9   -0.387320  0.683257 -0.980812 -0.243531
# 10  -1.335613  0.838067  0.812473 -0.169003
# 11   1.919498 -1.382899  0.148592 -0.797455
# 12  -0.316814  0.314698  0.375517 -0.271593
# 13   1.023295  0.436083  0.238844 -0.360544
# 14   1.014512 -1.149693  0.401950 -0.561943
# 15  -0.266168  0.417535 -0.546206 -1.569385
# 16  -1.392809 -0.789943  0.467106  0.267582
# 17   1.791098  0.713750 -0.800917 -0.972445
# 18   1.472147  0.354580  0.204868  1.385542
# 19   0.138798 -1.974603  1.693968  0.720460
# ...

# %%
col = data[1]

# %%
col[np.abs(col)>3]
# Out:
# 25    -3.033969
# 283   -3.082805
# 457   -3.047425
# 666   -3.245415
# 742    3.733917
# 834    3.230679
# Name: 1, dtype: float64

# %%
data[np.abs(col)>3]
# Out:
#             0         1         2         3
# 25  -0.243949 -3.033969  0.290266 -1.544901
# 283 -0.405932 -3.082805 -0.076317 -0.624504
# 457  1.771034 -3.047425  0.192084 -0.858944
# 666 -0.778403 -3.245415 -0.933318  0.108017
# 742 -0.767963  3.733917 -2.175238  0.424041
# 834 -2.189217  3.230679 -0.698682  0.983105
