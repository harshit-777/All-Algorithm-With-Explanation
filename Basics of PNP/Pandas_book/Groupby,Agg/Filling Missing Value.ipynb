# %% [markdown]
# # Extended Slices

# %%
l = range(4)

# %%
print(l)
# Out:
# range(0, 4)

# %%
l[::2]
# Out:
# range(0, 4, 2)

# %% [markdown]
# ## Filling Missing Values

# %%
s = pd.Series(np.random.randn(6))

# %%
s[::2] = np.nan

# %%
s
# Out:
# 0         NaN
# 1   -1.573598
# 2         NaN
# 3    0.242996
# 4         NaN
# 5    0.042170
# dtype: float64

# %%
s.fillna(s.mean())
# Out:
# 0   -0.429478
# 1   -1.573598
# 2   -0.429478
# 3    0.242996
# 4   -0.429478
# 5    0.042170
# dtype: float64
