# %%
val = 'a,b,c,aayush,000Hello World0'

# %%
S = val.strip('0')

# %%
S
# Out:
# 'a,b,c,aayush'

# %%
sp = val.split(',')

# %%
sp
# Out:
# ['a', 'b', 'c', 'aayush']

# %%
val.count(',')
# Out:
# 3
