# %%
# %matplotlib inline
import datetime

# %%
df = pd.read_csv('Matplot_Finacnial.csv',index_col=0,parse_dates=True)

# %%
df.head()
# Out:
#           Unnamed: 0.1     SPX
# 0  1990-02-01 00:00:00  328.79
# 1  1990-02-02 00:00:00  330.92
# 2  1990-02-05 00:00:00  331.85
# 3  1990-02-06 00:00:00  329.66
# 4  1990-02-07 00:00:00  333.75

# %%
fig =  plt.figure()
ax = fig.add_subplot(1,1,1)

spx = df['SPX']

spx.plot(ax=ax,style='k-')

# %%
crisis_data = [(datetime(2007,10,11), 'Peak of bull market'),
               (datetime(2008,3,12), 'Bear Stearns Fails'),
               (datetime(2008,9,15), 'Lehman Bankruptcy')]
# Out:
# ---------------------------------------------------------------------------
# TypeError                                 Traceback (most recent call last)
# <ipython-input-15-59d452796772> in <module>
# ----> 1 crisis_data = [(datetime(2007,10,11), 'Peak of bull market'),
#       2                (datetime(2008,3,12), 'Bear Stearns Fails'),
#       3                (datetime(2008,9,15), 'Lehman Bankruptcy')]
#
# TypeError: 'module' object is not callable
