# %% [markdown]
# # List Comprehensions
#
# ##  [expr for val in collection if condition]
#
#
# -This is equivalent to the following for loop:
# - result = [ ]
#     - *for val in collection:
#          - *if condition:
#               - *result.append(expr)

# %%
s = ['a', 'as', 'bat', 'carrrrrr', 'dove', 'pythoon']

# %%
[ x.upper()    for x in s     if len(x)>2]
# Out:
# ['BAT', 'CARRRRRR', 'DOVE', 'PYTHOON']

# %% [markdown]
# # Dict Comprehensions
#
#
# ## dict_comp = {key-expr : value-expr   ---- for value in collection  ----  if condition}

# %%
unique_len = {len(x)   for x in s }

# %%
unique_len
# Out:
# {1, 2, 3, 4, 7, 8}

# %%
set(map(len,s))
# Out:
# {1, 2, 3, 4, 7, 8}

# %%
loc_map  = {val:index  for index,val in enumerate(s)}

# %%
loc_map
# Out:
# {'a': 0, 'as': 1, 'bat': 2, 'carrrrrr': 3, 'dove': 4, 'pythoon': 5}

# %% [markdown]
# ## Nested list comprehension

# %%
all_data = [['John', 'Emily', 'Michael', 'Mary', 'Steven'],['Maria', 'Juan', 'Javier', 'Natalia', 'Pilar']]

# %%
result = [name    for names in all_data    for name in names     if name.count('e')>=2]

# %%
result
# Out:
# ['Steven']

# %% [markdown]
# ## tuple comp

# %%
tup = [(1, 2, 3), (4, 5, 6), (7, 8, 9)]

# %%
faltten = [x    for i in tup   for x in i]

# %%
faltten
# Out:
# [1, 2, 3, 4, 5, 6, 7, 8, 9]
