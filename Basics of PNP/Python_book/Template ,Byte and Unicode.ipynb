# %%
t = '{0:.3f} {1:s} are worth ${2:d}'

# %% [markdown]
# - {0:.2f} means floating point with two decimal
# - {1:s} means second argument is string
# - {2:d} exact  integer

# %%
t.format(7.2568,'Pesos',45)
# Out:
# '7.257 Pesos are worth $45'

# %% [markdown]
# # Bytes and Unicode

# %%
v = "español"

# %%
v
# Out:
# 'español'

# %%
v_utf8 = v.encode('utf-8')

# %%
v_utf8
# Out:
# b'espa\xc3\xb1ol'

# %%
type(v_utf8)
# Out:
# bytes

# %%
v_latin = v.encode('latin1')
v_latin
# Out:
# b'espa\xf1ol'

# %%
bytes_val = b'this is bytes'

# %%
bytes_val
# Out:
# b'this is bytes'

# %%
d = bytes_val.decode('utf-8')

# %%
d
# Out:
# 'this is bytes'
