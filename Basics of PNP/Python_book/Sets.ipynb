# %% [markdown]
# # Sets
#
# - A set is an unordered collection of unique elements.
# - You can think of them like dicts,but keys only, no values.
# - A set can be created in two ways: via the set function or via a set literal with curly braces:

# %%
set([2,5,8,9,4,3,1,1,8,9,3])
# Out:
# {1, 2, 3, 4, 5, 8, 9}

# %%
{4,5,8,7,9,6,2,1,2,3,4,7,9,9,32}
# Out:
# {1, 2, 3, 4, 5, 6, 7, 8, 9, 32}

# %% [markdown]
# ## Operation on sets

# %%
a = {1, 2, 3, 4, 5}
b = {3, 4, 5, 6, 7, 8}

# %%
print('Union---->',a.union(b))
print('Union---->',a|b)
# Out:
# Union----> {1, 2, 3, 4, 5, 6, 7, 8}
# Union----> {1, 2, 3, 4, 5, 6, 7, 8}

# %%
print('intersection---->',a.intersection(b))
print('intersection---->',a & b)
# Out:
# intersection----> {3, 4, 5}
# intersection----> {3, 4, 5}

# %%
print('Diff',a.difference(b))
# Out:
# Diff {1, 2}

# %%
set_to_tuple = {tuple(a)}

# %%
set_to_tuple
# Out:
# {(1, 2, 3, 4, 5)}
