# %% [markdown]
# The built-in bisect module implements binary search and insertion into a sorted list.
# bisect.bisect finds the location where an element should be inserted to keep it sor‐
# ted, while bisect.insort actually inserts the element into that location:

# %%
import bisect

# %%
c = [1,2,5,5,7,9,4,5,7,8,9,1]

# %%
c.sort()

# %%
c
# Out:
# [1, 1, 2, 4, 5, 5, 5, 7, 7, 8, 9, 9]

# %%
bisect.bisect(c,2)
# Out:
# 3

# %%
bisect.bisect(c,6)
# Out:
# 7

# %%
bisect.insort(c,6)

# %%
c
# Out:
# [1, 1, 2, 4, 5, 5, 5, 6, 7, 7, 8, 9, 9]
