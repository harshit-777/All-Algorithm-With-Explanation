# %%
from datetime import datetime,date,time

# %%
dt = datetime(2020,4,20,10,15,18)

# %%
dt.day
# Out:
# 20

# %%
dt.year
# Out:
# 2020

# %%
dt.strftime('%m/%d/%Y %H:%M')
# Out:
# '04/20/2020 10:15'

# %% [markdown]
# ## Difference between time

# %%
dt2  = datetime(2015,5,8,12,45,26)

# %%
change = dt - dt2

# %%
change
# Out:
# datetime.timedelta(days=1808, seconds=77392)
