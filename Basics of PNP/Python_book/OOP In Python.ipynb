# %% [markdown]
# # OOPS

# %%
class Home:
    pass

# %%
home_1 = Home() #Constructore

# %%
home_1

# %%
home_1.door = 15
home_1.window = 40

# %% [markdown]
# Bad approch

# %%
#lets make in proper way

# %%
dir(Home)
# Out:
# ['__class__',
#  '__delattr__',
#  '__dict__',
#  '__dir__',
#  '__doc__',
#  '__eq__',
#  '__format__',
#  '__ge__',
#  '__getattribute__',
#  '__gt__',
#  '__hash__',
#  '__init__',
#  '__init_subclass__',
#  '__le__',
#  '__lt__',
#  '__module__',
#  '__ne__',
#  '__new__',
#  '__reduce__',
#  '__reduce_ex__',
#  '__repr__',
#  '__setattr__',
#  '__sizeof__',
#  '__str__',
#  '__subclasshook__',
#  '__weakref__']

# %%
# __init__ act like constructore

# %%
class NewHome:
    def __init__(self,window,door,fan):
        self.window = window
        self.door = door
        self.fan = fan

# %%
NewHome_1 = NewHome(10,5,'Bajaj')

# %% [markdown]
# - here self is taking refrence of object(NewHome_1) and assigning the value of window door and fan

# %%
NewHome_2 = NewHome(15,20,'Usha')

# %%
print(NewHome_1.window)
# Out:
# 10

# %%
print(NewHome_2.fan)
# Out:
# Usha

# %%
class NewHome:
    def __init__(self,window,door,fan):
        self.window = window
        self.door = door
        self.fan = fan
        
    def company_of_fan(self):
        return "This House Uses {} company fan".format(self.fan)

# %%
NewHome_2.company_of_fan()
# Out:
# 'This House Uses Usha company fan'

# %%
# Again run Newhome_1 and NewHome_2
