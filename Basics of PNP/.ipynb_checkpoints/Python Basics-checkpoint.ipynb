# %% [markdown]
# # Basics of Python

# %%
a = 10 * 'H'

# %%
type(a)
# Out:
# str

# %%
type(True)
# Out:
# bool

# %% [markdown]
# ## Variable Assigment

# %%
b = 10

# %%
type(b)
# Out:
# int

# %%
print("Hello")
# Out:
# Hello

# %% [markdown]
# ## Format

# %%
a = 'AAyush'
b = 'Patidar'
print('name {} and surname {}'.format(a,b))
# Out:
# name AAyush and surname Patidar

# %%
print('name {first} and surname {last}'.format(last=b,first=a))
# Out:
# name AAyush and surname Patidar

# %% [markdown]
# ## Len

# %%
len(a)
# Out:
# 6

# %%
len(b)
# Out:
# 7

# %% [markdown]
# ## List
# Are Mutable
# content any elemnt

# %%
c = []

# %%
len(c)
# Out:
# 0

# %%
type(c)
# Out:
# list

# %%
d = list()

# %%
type(d)
# Out:
# list

# %% [markdown]
# ## Append

# %%
d = [1,2,3,4,5]

# %%
type(d)
# Out:
# list

# %%
d.append('Aayush')

# %%
d
# Out:
# [1, 2, 3, 4, 5, 'Aayush']

# %%
d.append(['Harshit','Name']) #Nested list

# %%
d
# Out:
# [1, 2, 3, 4, 5, 'Aayush', ['Harshit', 'Name']]

# %% [markdown]
# ## Indexing

# %%
d[0]
# Out:
# 1

# %%
d[4]
# Out:
# 5

# %%
d[:]
# Out:
# [1, 2, 3, 4, 5, 'Aayush', ['Harshit', 'Name']]

# %%
d[1:]
# Out:
# [2, 3, 4, 5, 'Aayush', ['Harshit', 'Name']]

# %%
d[2:5]
# Out:
# [3, 4, 5]

# %%
d[-1]
# Out:
# ['Harshit', 'Name']

# %%
d[-5:-1]
# Out:
# [3, 4, 5, 'Aayush']

# %% [markdown]
# ## insert
#
# - here parameters are index number and value we want to assign

# %%
d.insert(1,'Smart')

# %%
d
# Out:
# [1, 'Smart', 2, 3, 4, 5, 'Aayush', ['Harshit', 'Name']]

# %% [markdown]
# ## Extend
#
# - extend will add elments to list

# %%
d.extend([456,'Somakhedi'])

# %%
d
# Out:
# [1,
#  'Smart',
#  2,
#  3,
#  4,
#  5,
#  'Aayush',
#  ['Harshit', 'Name'],
#  456,
#  'Somakhedi',
#  456,
#  'Somakhedi']

# %% [markdown]
# ## pop-count-min-max-sum

# %%
d.pop(-1)
# Out:
# 456

# %%
d
# Out:
# [1,
#  'Smart',
#  2,
#  3,
#  4,
#  5,
#  'Aayush',
#  ['Harshit', 'Name'],
#  456,
#  'Somakhedi',
#  'smart',
#  'Smart']

# %%
len(d)
# Out:
# 12

# %%
d.count(1) #means 1 is present 1 time
# Out:
# 1

# %%
d.insert(-1,'Smart')

# %%
d
# Out:
# [1,
#  'Smart',
#  2,
#  3,
#  4,
#  5,
#  'Aayush',
#  ['Harshit', 'Name'],
#  456,
#  'Somakhedi',
#  'smart',
#  'Smart',
#  'Smart']

# %%
d.count('Smart')
# Out:
# 3

# %%
i = [1,58,69,7,56]

# %%
min(i)
# Out:
# 1

# %%
max(i)
# Out:
# 69

# %%
sum(i)
# Out:
# 191

# %%
i*2 #it means i will double the elemnts
# Out:
# [1, 58, 69, 7, 56, 1, 58, 69, 7, 56]

# %% [markdown]
# ## Sets
# - iterable
# - mutable
# - no duplicate elemets
# - this based on hash table
# - ste dose not support indexing

# %%
q = set()

# %%
print(type(q))
# Out:
# <class 'set'>

# %%
q = {1,2,3,4,3,2,5,6,7,5}

# %%
q
# Out:
# {1, 2, 3, 4, 5, 6, 7}

# %%
q.add('aayush')

# %%
q
# Out:
# {1, 2, 3, 4, 5, 6, 7, 'aayush'}

# %% [markdown]
# ## Dictionaries
# - changeable
# - indexed
# - use {}
# - assign using key value pair
# - if we give same key with another name it will overwrite it(just remember will see it)

# %%
dic= {}

# %%
print(type(dic))
# Out:
# <class 'dict'>

# %%
dic= {'Name':'Aayush','Surname':'Patidar','Age':22}

# %%
dic
# Out:
# {'Name': 'Aayush', 'Surname': 'Patidar', 'Age': 22}

# %%
dic.keys()
# Out:
# dict_keys(['Name', 'Surname', 'Age'])

# %%
dic.values()
# Out:
# dict_values(['Aayush', 'Patidar', 22])

# %% [markdown]
#  ## For loop

# %%
for i in dic:  
    print(i)
# Out:
# Name
# Surname
# Age

# %%
for i in dic.values():
    print(i)
# Out:
# Aayush
# Patidar
# 22

# %%
for i in dic.items():
    print(i)
# Out:
# ('Name', 'Aayush')
# ('Surname', 'Patidar')
# ('Age', 22)

# %%
# to add new key value pair
dic['place'] = 'Somakhedi'

# %%
dic
# Out:
# {'Name': 'Aayush', 'Surname': 'Patidar', 'Age': 22, 'place': 'Somakhedi'}

# %%
#if we take same value of key
dic['place'] = 'Pune'

# %%
dic
# Out:
# {'Name': 'Aayush', 'Surname': 'Patidar', 'Age': 22, 'place': 'Pune'}

# %% [markdown]
# ## Neested Dictionary

# %%
dic1 = {'AAyush':'HArshit'}
dic2 = {'Patidar':'Pati'}
nested_dic = {'name':dic1,'Surname':dic2}

# %%
nested_dic
# Out:
# {'name': {'AAyush': 'HArshit'}, 'Surname': {'Patidar': 'Pati'}}

# %%
nested_dic['name']['AAyush']
# Out:
# 'HArshit'

# %% [markdown]
# ## Tuples
# - cant change
# - immutable
# - () round
# - tuple assig. not change but hole tuple can be change
# - we cant perform operation it we can only perform replacemnet

# %%
tup =tuple()

# %%
type(tup)
# Out:
# tuple

# %%
tup = ('AAyush','Harshit')

# %%
tup[0]
# Out:
# 'AAyush'

# %%
tup[0] = 'Patidar'
# Out:
# ---------------------------------------------------------------------------
# TypeError                                 Traceback (most recent call last)
# <ipython-input-107-09c22791121c> in <module>
# ----> 1 tup[0] = 'Patidar'
#
# TypeError: 'tuple' object does not support item assignment

# %%
tup = ('Patidar')

# %%
tup
# Out:
# 'Patidar'

# %% [markdown]
# # Functions

# %%
n = 24

if num%2 == 0:
    print('Even')
