# %% [markdown]
# # Pandas
# - is open source
# - BSD-licnsed Lib provide high Performance
# - easy to use
# - used is data analysis

# %%
import pandas as pd 
import numpy as np

# %% [markdown]
# ## DataFrame

# %%
df = pd.DataFrame(np.arange(0,20).reshape(4,5),index=['R1','R2','R3','R5'],columns=['C1','C2','C3','C4','C5'])

# %%
df.head()
# Out:
#     C1  C2  C3  C4  C5
# R1   0   1   2   3   4
# R2   5   6   7   8   9
# R3  10  11  12  13  14
# R5  15  16  17  18  19

# %% [markdown]
# ## loc and iloc
#
# - .loc--> location
# - .iloc-->index location

# %%
df.loc['R1']
# Out:
# C1    0
# C2    1
# C3    2
# C4    3
# C5    4
# Name: R1, dtype: int64

# %%
type(df)
# Out:
# pandas.core.frame.DataFrame

# %%
type(df.loc['R1'])
# Out:
# pandas.core.series.Series

# %% [markdown]
# series are any one row or any one coloums

# %%
df.iloc[:,:]
# Out:
#     C1  C2  C3  C4  C5
# R1   0   1   2   3   4
# R2   5   6   7   8   9
# R3  10  11  12  13  14
# R5  15  16  17  18  19

# %%
df.iloc[2:4,2:]
# Out:
#     C3  C4  C5
# R3  12  13  14
# R5  17  18  19

# %%
type(df.iloc[2:4,2:])
# Out:
# pandas.core.frame.DataFrame

# %%
#  to convert into array
j=df.iloc[:,1:].values
j
# Out:
# array([[ 1,  2,  3,  4],
#        [ 6,  7,  8,  9],
#        [11, 12, 13, 14],
#        [16, 17, 18, 19]])

# %%
type(j)
# Out:
# numpy.ndarray

# %% [markdown]
# ## df.isnull

# %%
df.isnull()
# Out:
#        C1     C2     C3     C4     C5
# R1  False  False  False  False  False
# R2  False  False  False  False  False
# R3  False  False  False  False  False
# R5  False  False  False  False  False

# %%
df.isnull().sum()
# Out:
# C1    0
# C2    0
# C3    0
# C4    0
# C5    0
# dtype: int64

# %% [markdown]
# ## value_counts()

# %%
df['C1'].value_counts()
# Out:
# 15    1
# 5     1
# 10    1
# 0     1
# Name: C1, dtype: int64

# %%
df['C1'].unique()
# Out:
# array([ 0,  5, 10, 15])

# %% [markdown]
# ## Reading csv file

# %%
df1  = pd.read_csv('whitewine.csv')
