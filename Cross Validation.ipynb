# %% [markdown]
# # Cross Validation
#
# ## Why Cross Validation-
#
# - In our Train test split we have the parameter called random_state it means how many random state we are selecting or how many data points are passed in one iteration
#
# - Suppose we have 1000 data points we divide 70:30 ratio of our train test split
# - it we pass
#
# #### Case1 - random_state = 0 and accu = 85%
# #### Case2 -random_state = 40 and accu= 87%
#
# - Its very hard to tell how accurate is our model to prevent such kind of variation we use cross validatation

# %% [markdown]
# ## 1 Leave One Out CV (LOOCV)
#
# - 1000 records
# - Selectiong one data point as test and other perform taining
# - it will do for each iteration
#
#
# ![image.png](attachment:image.png)
#
#
# - DISADVANTAGE-
# - It will take lot of  time for computation
# - Low bias (error rate will high)
#
#
# so we use k-fold

# %% [markdown]
# ## 2 K-fold Cross Validation
#
# - we select a k value
# - K = number of experiment
# - suppose  we have 1000 records
# - lets assume k=5
# - 1000/5 = 200
# - Test data = 200 for exp 1 we get acc2
# - test data = next 200 for exp2 get acc2
# - Similar pattern follow
# - WE FIND MEAN OF ALL ACCURACY
# - we can also give MIN & MAX of ACCU
#
#
# ![image.png](attachment:image.png)
#
#
# - Diadvantage-
#
# - For Binary Classsificaton we get imbalanced dataset
# - to solve it we have

# %% [markdown]
# ## 3 Stratified Cross Validation
#
# - every time when data is selected
# - Number of instance of each class is taken as proportion
# - If we have some imbalance dataset
#
#
# ![image.png](attachment:image.png)

# %% [markdown]
# ## 4 Time series CV
#
# - Time data
# - Suppose we have
# - INPUT-----Day1,D1,D2,D3,D4,D5
# - PRED------D6,D7
#
#
# - For CV we take
#
# ===========================================
#
# - D1,D2,D3,D4,D5 ----D6 (output)
#
# ===========================================
#
# - D2,D3,D4,D5,D6-----D7(output)
#
#
#
# ![image.png](attachment:image.png)
