# %% [markdown]
# # KNN
# - K nearest neighbors is a simple algorithm that stores all available cases and classifies new cases based on a similarity measure (e.g., distance functions).
#
# - KNN can be used for both classification and regression predictive problems. However, it is more widely used in classification problems in the industry. To evaluate any technique we generally look at 3 important aspects:
#
# 1. Ease to interpret output
#
# 2. Calculation time
#
# 3. Predictive Power
#
#
# ## KNN Classification
#
# - ![image.png](attachment:image.png)
#
#
# - We can see the different Category in above plot
# - We Choose a Query
# - And algo apply in following steps

# %% [markdown]
# ![image.png](attachment:image.png)

# %% [markdown]
# ![image.png](attachment:image.png)

# %% [markdown]
# ## How To Calculate Distance
#
# - we use different technique because suppose we have two points to measure the distance between them which is near we will take consider that point
# - To caluculate we use following-
#
#
#
# ### Euclidean Distance
#
# - we have two points x1,y1 and x2,y2
# - PGT we use for caluclation
#
#
#
# ![image.png](attachment:image.png)

# %% [markdown]
# ### Manhattan Distance
#
#
# - we have two points which are locate
#
# ![image.png](attachment:image.png)
#
#
# - we take absolute of |x2-x1| + |y2-y1|

# %% [markdown]
# ![image.png](attachment:image.png)

# %% [markdown]
# ## DataSet and Outlier
#
# - supose we have the imbalanced data set like 900:100
# - If we have new point between them,its hard to decide in which catergory it belongs
# - It will be biased to one category
#
#
#
#
# - If we have outliers then definetly it will imapacted
#
# ![image.png](attachment:image.png)

# %% [markdown]
#  ## KNN Regrssion
#
#
#  ![image.png](attachment:image.png)
#
# - it will find mean of all nearest neighbours

# %% [markdown]
# ![image.png](attachment:image.png)
