# %% [markdown]
# # BAYE'S THEROEM
#
# ## Conditional Probabalility
#
# - Conditional probability is the probability of one event occurring with some relationship to one or more other events
#
# - ![image.png](attachment:image.png)
#
#
# ### For Blue
# - P(A) = 2/5
# - Prob of B when A is done
# - Means we selected one blue for next blue
# - P(B|A) = 1/4
# - P(A intersection B) = 2/5 * 1/4

# %% [markdown]
# ![image.png](attachment:image.png)

# %% [markdown]
# ![image.png](attachment:image.png)

# %% [markdown]
# For Some NAme we can write-
#
# ![image.png](attachment:image.png)
