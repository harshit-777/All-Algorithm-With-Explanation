# %%
df = pd.read_table('https://raw.githubusercontent.com/justmarkham/pycon-2016-tutorial/master/data/sms.tsv',header=None,names=['label','message'])
# Out:
# /home/ind/anaconda3/lib/python3.7/site-packages/ipykernel_launcher.py:1: FutureWarning: read_table is deprecated, use read_csv instead, passing sep='\t'.
#   """Entry point for launching an IPython kernel.

# %%
df.to_csv('sms.csv')

# %%
import pandas as pd

# %%
sms_df = pd.read_csv('sms.csv',index_col=0)

# %%
sms_df.head()
# Out:
#   label                                            message
# 0   ham  Go until jurong point, crazy.. Available only ...
# 1   ham                      Ok lar... Joking wif u oni...
# 2  spam  Free entry in 2 a wkly comp to win FA Cup fina...
# 3   ham  U dun say so early hor... U c already then say...
# 4   ham  Nah I don't think he goes to usf, he lives aro...

# %%
sms_df.label.value_counts()
# Out:
# ham     4825
# spam     747
# Name: label, dtype: int64

# %%
sms_df.isnull().sum()
# Out:
# label      0
# message    0
# dtype: int64

# %%
sms_df['label_num'] = sms_df.label.map({'ham':0,'spam':1})

# %%
sms_df
# Out:
#      label                                            message  label_num
# 0      ham  Go until jurong point, crazy.. Available only ...          0
# 1      ham                      Ok lar... Joking wif u oni...          0
# 2     spam  Free entry in 2 a wkly comp to win FA Cup fina...          1
# 3      ham  U dun say so early hor... U c already then say...          0
# 4      ham  Nah I don't think he goes to usf, he lives aro...          0
# 5     spam  FreeMsg Hey there darling it's been 3 week's n...          1
# 6      ham  Even my brother is not like to speak with me. ...          0
# 7      ham  As per your request 'Melle Melle (Oru Minnamin...          0
# 8     spam  WINNER!! As a valued network customer you have...          1
# 9     spam  Had your mobile 11 months or more? U R entitle...          1
# 10     ham  I'm gonna be home soon and i don't want to tal...          0
# 11    spam  SIX chances to win CASH! From 100 to 20,000 po...          1
# ...

# %%
X = sms_df.message

# %%
y = sms_df.label_num

# %% [markdown]
# ## train test split

# %%
from sklearn.model_selection import train_test_split

# %%
X_train, X_test, y_train, y_test = train_test_split(X, y, random_state=1)

# %% [markdown]
# ## CountVectorizer

# %%
from sklearn.feature_extraction.text import CountVectorizer

# %%
count = CountVectorizer()

# %%
X_train_data = count.fit_transform(X_train)

# %%
X_train_data
# Out:
# <4179x7456 sparse matrix of type '<class 'numpy.int64'>'
# 	with 55209 stored elements in Compressed Sparse Row format>

# %%
X_test_data = count.transform(X_test)

# %%
X_test_data
# Out:
# <1393x7456 sparse matrix of type '<class 'numpy.int64'>'
# 	with 17604 stored elements in Compressed Sparse Row format>

# %% [markdown]
# ## Multinomial

# %%
from sklearn.naive_bayes import MultinomialNB

# %%
nb = MultinomialNB()

# %%
nb.fit(X_train_data,y_train)
# Out:
# MultinomialNB(alpha=1.0, class_prior=None, fit_prior=True)

# %%
pred = nb.predict(X_test_data)

# %%
pred
# Out:
# array([0, 0, 0, ..., 0, 1, 0])

# %%
from sklearn.metrics import accuracy_score

# %%
print('accuracy',metrics.accuracy_score(y_test,pred)*100)
# Out:
# accuracy 98.85139985642498

# %%
metrics.confusion_matrix(y_test,pred)
# Out:
# array([[1203,    5],
#        [  11,  174]])

# %%
pred_prob = nb.predict_proba(X_test_data)

# %%
pred_prob
# Out:
# array([[9.97122551e-01, 2.87744864e-03],
#        [9.99981651e-01, 1.83488846e-05],
#        [9.97926987e-01, 2.07301295e-03],
#        ...,
#        [9.99998910e-01, 1.09026171e-06],
#        [1.86697467e-10, 1.00000000e+00],
#        [9.99999996e-01, 3.98279868e-09]])

# %%
df3 = pd.DataFrame(pred_prob)

# %%
plt.plot(df3)
