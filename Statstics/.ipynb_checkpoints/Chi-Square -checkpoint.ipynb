# %% [markdown]
# # Chi-Square test
#
# - The test is applied when you have two categorical variables from a single population.
# - It is used to determine whether there is a significant association between the two variables.
#
# - X ~N(0,1)
# here N = noramlized curve in which
# 0 is mean value
# 1 is var
#
# - Q(chi notation)
#
# ![image.png](attachment:image.png)
#
#
# - O = observed
# - E = Expected

# %% [markdown]
# ![image.png](attachment:image.png)
#
# the lumps go high as degree of freedom increrase
#
# - Degree of freedom = (n-1)
#
# - it uses sinificance value alpha = 0.05 ie. 5%
