# %% [markdown]
# A tree has many analogies in real life, and turns out that it has influenced a wide area of machine learning, covering both classification and regression. In decision analysis, a decision tree can be used to visually and explicitly represent decisions and decision making. As the name goes, it uses a tree-like model of decisions.
#
#
# - Tree last node is called final class label
# - f1,f2,f3--- output(T/N)
# - Work on ID3() means select right attribute
# - For selecting right feature we need ENtropy
#
# # Entropy -
#
# - Use to calculate purity of the subset
# - Aim to get Pure Subset
# - Works  on pure subsplits coz we are getting Yes and No both we  go further until we dont get  full Yes or NO
#
#
#
# - ![image.png](attachment:image.png)
#
#
#
#
# - for impure subset the entropy is always one like the case where we have 3 Yes or 2 No
#
# - For sum of all the entropy it uses concept of Information Gain
#
# - Always ranges between Zero to One

# %% [markdown]
# ![image.png](attachment:image.png)
#
#
# - Entropy=O --means 5 yes 0 No (Pure and stop Split) become Leaf Node
# - Entropy=1 --means some Yes and Some no

# %% [markdown]
# # GINI Impurity
#
# ![image.png](attachment:image.png)
#
#
#
# - Why-
#
# - For 50-50 Scenerio
# - GI = 1 - [p+**2 + p-**2]
# - GI = 1 - [0.25+0.25]
# - GI = 0.5
#
#
#
# - Value is Less then entropy
# - Reason computational easily
# - Take less Time

# %% [markdown]
# ![image.png](attachment:image.png)

# %% [markdown]
# # Information Gain
#
# - Information gain is the reduction in entropy or surprise by transforming a dataset and is often used in training decision trees. Information gain is calculated by comparing the entropy of the dataset before and after a transformation
#
# - Compute average of all entropy
# - To compare between splits which is better
#
#
#
# - ![image.png](attachment:image.png)

# %% [markdown]
# # Decision Tree Split For Numerical
#
#
#
# - Step 1- It must in form of Sorted Order
# - Step 2- Specify threshold
# - Step 3- Compare value with each record and crate tree for each record
# - Step 4- Calculate Entropy and Gain
# - Step 5- Result is taken with better gain
#
# ![image.png](attachment:image.png)
