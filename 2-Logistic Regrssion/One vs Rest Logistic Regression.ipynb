# %% [markdown]
# # One vs Rest
#
# - On their own, logistic regressions are only binary classifiers, meaning they cannot handle target vectors with more than two classes. However, there are clever extensions to logistic regression to do just that. In one-vs-rest logistic regression (OVR) a separate model is trained for each class predicted whether an observation is that class or not (thus making it a binary classification problem). It assumes that each classification problem (e.g. class 0 or not) is independent.
#
#
# ![image.png](attachment:image.png)

# %% [markdown]
# here we will create three feature
#
# - Case1- we will treat 2 feature and same one as different and we will create model M1(from x1)
#
# - Similarly M2(from x2) and M3(from x3) can be crated
#
# - After that it give probability [0.20,0.25,0.65]
#
# - which is giving high prob value in that new data is belong.
#
# - Internally in logistic reg is uses OVR parameter

# %%
from sklearn.linear_model import LogisticRegression
from sklearn import datasets
from sklearn.preprocessing import StandardScaler
# Out:
# /home/ind/anaconda3/lib/python3.7/importlib/_bootstrap.py:219: RuntimeWarning: numpy.ufunc size changed, may indicate binary incompatibility. Expected 192 from C header, got 216 from PyObject
#   return f(*args, **kwds)

# %%
iris = datasets.load_iris()
X = iris.data
y = iris.target

# %%
# Standarize features
scaler = StandardScaler()
X_std = scaler.fit_transform(X)

# %%
clf = LogisticRegression(random_state=0, multi_class='ovr')

# %%
model = clf.fit(X_std, y)
# Out:
# /home/ind/anaconda3/lib/python3.7/site-packages/sklearn/linear_model/logistic.py:433: FutureWarning: Default solver will be changed to 'lbfgs' in 0.22. Specify a solver to silence this warning.
#   FutureWarning)

# %%
new_observation = [[.5, .5, .5, .5]]

# %%
model.predict(new_observation)
# Out:
# array([2])

# %%
model.predict_proba(new_observation)
# Out:
# array([[0.08401839, 0.29392375, 0.62205786]])
