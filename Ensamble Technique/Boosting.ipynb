# %% [markdown]
# # ADABOOST
#
# - We are Combining weak Learner and making them strong
#
# - Only wrong records are passed to Base Learner

# %% [markdown]
# ![image.png](attachment:image.png)

# %% [markdown]
# ## Step 1-
# - Get Sample weight W = 1/n here n = 8
# - records assign same weight
# - Base Learner Dicision tree
# - Discision Tree used here is STUMPS(One depth)
#
# ![image.png](attachment:image.png)

# %% [markdown]
# ## Step 2-
# - for each data feature stumps are created
# - We select one the basic of entropy and Info gain
# - For inccorect classified data we find total error
# ![image.png](attachment:image.png)

# %% [markdown]
# ## Step 3-
#
# Total error = 1/n

# %% [markdown]
# Performance of stump = 1/2 * log * (1-TE)/TE = we get 0.97 by calculation
# ![image.png](attachment:image.png)

# %% [markdown]
# ## Step 4- For incorrct classification
# ![image.png](attachment:image.png)
#
#
# By puting values we will get 0.33

# %% [markdown]
# ## Step 5- Correct Classification
#
#
# ![image.png](attachment:image.png)
#
# by putting value we get 0.05

# %% [markdown]
# ## Step 6 -
#
# - When we sum all we dont get one
# - we dicide by sum of updated weight we get Normalized Value.
# - Based on Normalized we crate bucket
# - 0-0.007
# - 0.07-0.58....so on
# - It select random value look at value in our bucket select the wrong record
# - and process will go soo on we get new dataset with all wrong records
# - Create new Stumps again same above steps will go
#
# ![image.png](attachment:image.png)

# %% [markdown]
# ![image.png](attachment:image.png)

# %% [markdown]
# ![image.png](attachment:image.png)
