# %% [markdown]
# # Ensemble Technique
#
# - Used to reduce  Varience
#
# - Combining Multiple models
#
# - Ensemble learning helps improve machine learning results by combining several models. ... Ensemble methods are meta-algorithms that combine several machine learning techniques into one predictive model in order to decrease variance (bagging), bias (boosting), or improve predictions (stacking).
#
#
# ## Bagging or Bootstraping
#
# - We have data D and model are m1,m2...mn and n total number records
# - We will provide some sample data to each model
# - (D'm---->m1)  m<n
# - Again reshample the records and give it to model 2 we called row sampling with replacement
# - (D"m---->m2)
# - our model give output in form of 1 and 0
# - Voting Classifier is applied
# - we  select most voted classifier
#
#
# ![image.png](attachment:image.png)

# %% [markdown]
# ## Random Forest Classifier
#
#
# - A Random Forest is an ensemble technique capable of performing both regression and classification tasks with the use of multiple decision trees and a technique called Bootstrap Aggregation, commonly known as bagging
#
#
# ## Property of Random Forest
#
# - Base Learner  = Discission Tree
# - Because DT are Low Bias and High Varieance(overfitting)
# - Multiple DT  will have Varience
# - When we combine Multiple Model out put the high Varience will convert into low varience because DT become Expert when we provide specific data they get train on particular data set
# - will get high accuracy
#
#
#
# ![image.png](attachment:image.png)

# %% [markdown]
# ## Random Forest Regrssor
#
#
# FOR REGRESSION PROBLEM WE TAKE MEAN OR MEDIAN OF THAT OUTPUT
#
# IN SKLEARN IT FIND AVERAGE OUTPUT
#
#
# ![image.png](attachment:image.png)
